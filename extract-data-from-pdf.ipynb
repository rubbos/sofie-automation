# %%
from PIL import Image
from pdf2image import convert_from_path
import pytesseract
import cv2
import os
import spacy

# %%
file_path = 'testpdf/sofie_form.pdf'
doc = convert_from_path(file_path)
path, file_name = os.path.split(file_path)
file_base_name, file_extension = os.path.splitext(file_name)

# %%
txt = ''
for page_number, page_data in enumerate(doc):
    txt += pytesseract.image_to_string(page_data)

# %%
print(txt)
# Out:
# SOFIE Application 30% Tax Facility
#
# Social Fiscal International Expertise
#
#
#
# Introduction
#
# SOFI-expertise is a collaboration of the Dutch universities and research institutes. The 30% request is filed by your employer
# who handles all communication with us. In this form we ask information about your residence prior to the start of your
# employment and previous stays in the Netherlands.
#
# Request in-time:
#
# If the employer files the request within 4 months after the 1 st day of employment, the approval will take effect from the start
# of your employment. If we receive the request after these 4 months, the approval will start on the 1 st day of the month
# following the month when the request has been filed.
#
# Personal data
#
# For our assessment we request personal data. Please read our Privacy Statement in which we explain which data we collect,
# what we do with your data, and most importantly, what your rights are.
#
# Short track procedure
#
# In most situations SOFI-expertise can process the request independently, after which the tax administration can issue a
# decision/approval in appr. 1 month.
#
# Extended procedure
#
# Unfortunately, not all requests can be handled by SOFI-expertise this way. Sometimes the tax administration wants to review
# a case more in detail and asks employer and employee to submit the request including all the provided evidence in writing.
# These requests will not be handled by SOFI- expertise and hence need to be processed by the employer, or through an
# external 3 rd party.
#
# Please complete the form below, print it, sign it and share it with the representative of your employer.
#
# Form to be completed by employee
#
# Last Name, Initials Oerter, ALA
#
# Has agreed with the employer to a joint request for approval of the 30% Tax
# Facility.
#
# Authorizes SOFI-expertise to file the request for the 30% Tax Facility on behalf
# of the employee at the Dutch Tax and Customs Administration
# (Belastingdienst).
#
# Authorizes to keep the information provided by the employee on record for the
# duration of the retention periods mentioned in the Privacy Statement of SOFI-
# expertise,
#
# Is aware that the 30% Tax Facility, can only be applied correctly in the payroll
# administration if agreed upon in the employment contract, or in an addendum
#
# to the employment contract.
#
# I will provide a recent and updated CV to this application.
#
# Do you currently make use of the 30% tax facility with previous employer?
#
# @ No O Yes
#
# The following information is required for the assessment of your eligibility
# Date of arrival in the Netherlands: 01/08/2024 6 Um
#
#
#
# In case you have not moved yet, dd/mm/yyyy 6 CO NA
# please indicate the expected date of
# moving to the Netherlands:
# My address in the Netherlands is Address:
# (or will be): ° Oude Bennekomseweg 1
# Place: 6706 ER Wageningen
#
# In case you will not move to the Netherlands please indicate how often you expect to come and work in the Netherlands.
# Please give a detailed explanation (How many times, how long each time):
#
# The first ‘actual’ working day in the 01/08/2024 cm
# Netherlands:
#
# Place(s) of residence (registered or unregistered) during the 24 months prior to the start of the
# employment contract:
#
# Depending on your personal facts and circumstances we may need additional evidence regarding your place of residence.
# If you have lived in the Netherlands, or in a country that lies within a 150km radius of the closest Dutch border, we will ask for evidence
# that supports your place of residence during the 24 months prior to the start of your employment. This could be one of the following:
#
# 1. An abstract of the municipality records that proofs your residency at that address.
# 2. A copy of a rental contract and proof that you have paid rent over at least 17 out of the last 24 months.
# 3. Utility bills and proof of payment over at least 17 out of the last 24 months.
#
# If you cannot provide the above required evidence the SOFI-expertise consultant will discuss with the representative of the employer which
# additional information is required. Please do not include personal data that we are not asking for specifically. In case non-necessary data is
# provided we will kindly ask you to delete this data and upload it again.
#
# Date from: 94/01/2024 ©) °° = 3107/2024 ©
# Address: Burgweg 18
#
# Place: Bonn
#
# Country: Germany
#
# Date from: 19/10/2019 & © dd/mm/yyyy =
# Address: Waechterstr. 2
#
# Place: Rothenburg 0.d.T.
#
# Country: Germany
# Date from: 94/9/2024 &}) © 13/01/2024 &
#
# Address: Hoevestein 239
# Place: Wageningen
# Country: Netherlands
#
# Have you previously lived in the Netherlands?
# O No @ Yes
#
# In case you have been registered at the municipality, please enclose an overview of the historical
# registration. You can download this or make screen prints from your municipality with DigiD.
#
# Date from: 94/98/2020 &} © = 13/01/2024 &
#
# 1. Were you registered at the municipality?
#
# O No @ Yes
# 2. Did you deregister when you moved out of Netherlands?
#
# O No @ Yes
#
# Deregister date: 02/05/2024 ©
#
# Have you previously worked (paid or unpaid) in the Netherlands?
#
# O No @ Yes
#
# Date from: 94/91/2023 & fo 31/08/2023 cm
# Date from: 94/99/2022 f& © — 31/10/2022 =
# Date from: 94/11/2021 f& © — 31/12/2021 ©
#
# Have you previously been in the Netherlands for private reasons, such as study,
# holiday or family visits?
#
# O No @ Yes
#
# Date from: 94/9/2020 &) © — o10s/2023 &
#
# Have you previously worked for a Dutch employer outside the Netherlands, for
# example as a posted worker or working remotely?
#
# O No @ Yes
#
# Date from: 94/11/2023 &) © © 31/12/2023 &
#
# The undersigned declares to have filled out this form truthfully.
# Name: Leandra Oerter Date: 09/08/2024
#
# Signature:

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(txt)

# %%
# refactor this bs

def extract_text_between_keywords(txt, start_keyword, end_keyword=None):
    if start_keyword in txt:
        start_index = txt.index(start_keyword) + len(start_keyword)
        
        # Find the next newline
        end_index_newline = txt.find('\n', start_index)
        
        if end_keyword:
            # Find the specified end keyword
            end_index_keyword = txt.find(end_keyword, start_index)
            
            # Determine the smaller index to stop at: newline or end keyword
            if end_index_keyword != -1:
                end_index = min(end_index_newline, end_index_keyword)
            else:
                end_index = end_index_newline
        else:
            end_index = end_index_newline
        
        # Capture text up to the determined end index
        return txt[start_index:end_index].strip() if end_index != -1 else None
    return None

# Extract initials
initials_text = extract_text_between_keywords(txt, "Initials")
if initials_text:
    print("Found initials:", initials_text)
else:
    print("Keyword 'Initials' not found in the text.")

# Extract name until "Date: "
signature_name = extract_text_between_keywords(txt, "Name: ", "Date: ")
if signature_name:
    print(f"Found signature name: {signature_name}")
else:
    print("Keyword 'Name:' not found in the text.")
# Out:
# Found initials: Oerter, ALA
# Found signature name: Leandra Oerter
